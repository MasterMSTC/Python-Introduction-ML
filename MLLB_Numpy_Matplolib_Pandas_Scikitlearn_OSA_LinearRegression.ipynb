# %% [markdown]
# # <font color=#BB44>Python Introduction (MSTC)</font>
#
# ## [NumPy is the fundamental package for scientific computing with Python](http://www.numpy.org/)
# ![Imagen Numpy](http://www.numpy.org/_static/numpy_logo.png)
#
# ## [Matplotlib is a Python 2D plotting library](https://matplotlib.org/)
# ![Matplotlib Image](https://matplotlib.org/_static/logo2.png)
#
# ## [Python Data Analysis Library](https://pandas.pydata.org/)
# ![Pandas Image](https://pandas.pydata.org/_static/pandas_logo.png)
#
# ## [scikit-learn: Machine Learning in Python](http://scikit-learn.org/stable/)
# ![Scikit-learn Image](http://scikit-learn.org/stable/_static/scikit-learn-logo-small.png)

# %% [markdown]
# ---
#
# ## Read the OSA data (without empty patients and chars in "peso")

# %%
# Import pandas
import pandas as pd

# Assign spreadsheet filename to `file`
file = 'Info_BDApnea_QuironMalaga_rev1.xlsx'

# Load spreadsheet
xl = pd.ExcelFile(file)

# Print the sheet names
print(xl.sheet_names)
# Out:
# ['Hoja1', 'Hoja2']

# %%
# Load a sheet into a DataFrame by name: df1
df_tmp = xl.parse('Hoja1')

# %%
df_tmp
# Out:
#     Patient                                        Comentarios Audios tumbado  \
# 0     P0001  es el Patient0002 (fotos) 3 (sentado) y 4 (tum...             si
# 1     P0002          Es el Patient0006 (sentado) y 7 (tumbado)             si
# 2     P0003                                  Patient 8, 9 y 10             si
# 3     P0004                                    Patient 13 y 14     si_codigos
# 4     P0005                       Patient0015 los códigos QMH5     si_codigos
# 5     P0006                                               QMH6     si_codigos
# 6     P0007                                               QMH7     si_codigos
# 7     P0008                                               QMH8     si_codigos
# 8     P0009                                               QMH9     si_codigos
# 9     P0010                                              QMH10     si_codigos
# 10    P0011                                              QMH13     si_codigos
# 11    P0012                                              QMH14     si_codigos
# 12    P0013                                              QMH19      NO_UNAREP
# 13    P0014                                              QMH20      NO_UNAREP
# 14    P0015                                              QMH21      SI_UNAREP
# 15    P0016                                              QMH22      SI_UNAREP
# 16    P0017                                              QMH23      NO_UNAREP
# 17    P0018                                              QMH24      NO_UNAREP
# 18    P0019                                              QMH26      NO_UNAREP
# 19    P0020                                              QMH28      NO_UNAREP
# 20    P0021                                              QMH29      NO_UNAREP
# 21    P0022                                              QMH30      NO_UNAREP
# 22    P0023                                              QMH33      NO_UNAREP
# 23    P0024                                              QMH34      NO_UNAREP
# 24    P0025                                              QMH35      NO_UNAREP
# 25    P0026                                              QMH36      NO_UNAREP
# 26    P0027                                              QMH37      NO_UNAREP
# 27    P0028                                              QMH38      NO_UNAREP
# 28    P0029                                              QMH39      NO_UNAREP
# 29    P0030                                              QMH40      NO_UNAREP
# ..      ...                                                ...            ...
# 653   P0654                                QMH663(patient0728)      NO_UNAREP
# 654   P0655                                QMH664(patient0729)      NO_UNAREP
# 655   P0656                       QMH665(patient0730) Usa CPAP      NO_UNAREP
# 656   P0657                                QMH666(patient0731)      NO_UNAREP
# 657   P0658                                QMH667(patient0732)      NO_UNAREP
# 658   P0659                                QMH668(patient0733)      NO_UNAREP
# 659   P0660                                QMH669(patient0734)      NO_UNAREP
# 660   P0661                                QMH670(patient0735)      NO_UNAREP
# 661   P0662               QMH671(patient0736) Nuevas preguntas      NO_UNAREP
# 662   P0663                                QMH672(patient0737)      NO_UNAREP
# 663   P0664                                QMH673(patient0738)      NO_UNAREP
# 664   P0665                                QMH674(patient0739)      NO_UNAREP
# 665   P0666                                QMH675(patient0740)      NO_UNAREP
# 666   P0667                                QMH676(patient0741)      NO_UNAREP
# 667   P0668                                QMH677(patient0742)      NO_UNAREP
# 668   P0669                                QMH678(patient0743)      NO_UNAREP
# 669   P0670                                QMH679(patient0744)      NO_UNAREP
# 670   P0671                       QMH680(patient0745) usa CPAP      NO_UNAREP
# 671   P0672                                QMH681(patient0746)      NO_UNAREP
# 672   P0673                                QMH682(patient0747)      NO_UNAREP
# 673   P0674                                QMH683(patient0748)      NO_UNAREP
# 674   P0675                                QMH684(patient0749)      NO_UNAREP
# 675   P0676                                QMH685(patient0750)      NO_UNAREP
# 676   P0677                                QMH686(patient0751)      NO_UNAREP
# 677   P0678                       QMH687(patient0752) usa CPAP      NO_UNAREP
# 678   P0679                       QMH688(patient0753) usa CPAP      NO_UNAREP
# 679   P0680                                QMH689(patient0754)      NO_UNAREP
# 680   P0681                       QMH690(patient0755) usa CPAP      NO_UNAREP
# 681   P0682                                QMH691(patient0756)      NO_UNAREP
# 682   P0683  QMH692(patient0757) FOTOS BOCA y RESPIRACIONES...      NO_UNAREP
#
#     Fotos Audio fs KHz  Gender EPWORTH    IAH  \
# 0      si           16  hombre     NaN   71.0
# 1      si           16  hombre     NaN   29.6
# 2      si           16  hombre     NaN   56.0
# 3      si           16  hombre     NaN   19.7
# 4      si           16  hombre     NaN    9.0
# 5      si           16  hombre     NaN    2.0
# 6      si           16  hombre     NaN   34.0
# 7      si           16  hombre     NaN   60.0
# 8      si           16  hombre     NaN   22.0
# 9      si           16  hombre     NaN   11.0
# 10     si           16  hombre     NaN   14.2
# 11     si           16  hombre     NaN   10.0
# 12     si           16  hombre     NaN    3.7
# 13     si           16   mujer     NaN    7.0
# 14     si           16   mujer     NaN    5.0
# 15     si           16  hombre     NaN   26.0
# 16     si           16  hombre     NaN   22.0
# 17     si           16   mujer     NaN   10.0
# 18     si           16   mujer     NaN   15.0
# 19     si           16  hombre     NaN    4.3
# 20     si           16   mujer     NaN   20.0
# 21     si           16  hombre     NaN   56.0
# 22     si           16   mujer     NaN    4.0
# 23     si           16  hombre     NaN   53.6
# 24     si           16  hombre     NaN    2.1
# 25     si           16  hombre     NaN   27.0
# 26     si           16  hombre      12   47.0
# 27     no           16   mujer     NaN    5.9
# 28     si        55/16  hombre     NaN    9.0
# 29     si        55/16  hombre     NaN   32.0
# ..    ...          ...     ...     ...    ...
# 653    si        55/16  hombre     NaN    8.2
# 654    si        55/16  hombre     NaN   16.7
# 655    si        55/16  hombre     NaN   27.9
# 656    si        55/16  hombre     NaN    0.0
# 657    si        55/16   mujer     NaN    1.3
# 658    si        55/16  hombre      20    8.8
# 659    si        55/16  hombre     NaN    NaN
# 660    si        55/16  hombre     NaN   15.0
# 661    si        55/16  hombre     NaN   52.6
# 662    si        55/16  hombre      12   64.3
# 663    si        55/16   mujer     NaN    1.0
# 664    si        55/16  hombre     NaN   17.2
# 665    si        55/16   mujer     NaN    4.8
# 666    si        55/16  hombre     NaN   25.0
# 667    si        55/16  hombre     NaN   41.5
# 668    si        55/16  hombre     NaN    2.7
# 669    si        55/16   mujer     NaN   57.0
# 670    si        55/16  hombre     NaN    NaN
# 671    si        55/16   mujer     NaN  108.6
# 672    si        55/16   mujer     NaN    4.6
# 673    si        55/16  hombre      14   33.0
# 674    si        55/16   mujer     NaN    4.7
# 675    si        55/16  hombre     NaN   27.9
# 676    si        55/16   mujer     NaN   36.3
# 677    si        55/16  hombre     NaN    NaN
# 678    si        55/16  hombre     NaN    9.2
# 679    si        55/16  hombre     NaN   52.2
# 680    si        55/16  hombre     NaN    NaN
# 681    si        55/16   mujer     NaN    5.4
# 682    si        55/16   mujer     NaN   31.9
#
#                                  IAH Supino      IAH Lateral  ...  \
# 0                                        -1               -1  ...
# 1                                        -1               -1  ...
# 2                                        -1               -1  ...
# 3                                        -1               -1  ...
# 4                                        -1               -1  ...
# 5                                        -1               -1  ...
# 6                                        -1               -1  ...
# 7                                        -1               -1  ...
# 8                                        -1               -1  ...
# 9                                        -1               -1  ...
# 10                                       -1               -1  ...
# 11                                       -1               -1  ...
# 12                                       -1               -1  ...
# 13                                       -1               -1  ...
# 14                                       -1               -1  ...
# 15                                       -1               -1  ...
# 16                                       -1               -1  ...
# 17                                       -1               -1  ...
# 18                                       -1               -1  ...
# 19                                       -1               -1  ...
# 20                                       -1               -1  ...
# 21                                       -1               -1  ...
# 22                                       -1               -1  ...
# 23                                       -1               -1  ...
# 24                                       -1               -1  ...
# 25                                       -1               -1  ...
# 26                                       -1               -1  ...
# 27                                       -1               -1  ...
# 28                                       -1               -1  ...
# 29                              Severo > 30               -1  ...
# ..                                      ...              ...  ...
# 653                                    22.1              4.4  ...
# 654                   influencia posicional              NaN  ...
# 655                                    32.5             27.3  ...
# 656                             se descarta              NaN  ...
# 657                                     1.7              1.2  ...
# 658                                     NaN              NaN  ...
# 659                                     NaN              NaN  ...
# 660                                     NaN              NaN  ...
# 661                                    33.2             63.5  ...
# 662         sin cambios en decúbito lateral              NaN  ...
# 663                                     NaN              NaN  ...
# 664                                    29.3              7.6  ...
# 665                                      12              2.5  ...
# 666            minima influencia posicional              NaN  ...
# 667                                    59.6             34.4  ...
# 668                                     NaN              NaN  ...
# 669            minima influencia posicional              NaN  ...
# 670                                     NaN              NaN  ...
# 671                                     NaN              NaN  ...
# 672                                       1              5.1  ...
# 673           Decúbito lateral incalculable              NaN  ...
# 674                                     5.2                3  ...
# 675                                     NaN              NaN  ...
# 676                                     NaN             37.8  ...
# 677  IAH residual 12 estudio hecho con CPAP              NaN  ...
# 678                                    15.9              7.3  ...
# 679                                    53.4             50.3  ...
# 680                           NO disponible              NaN  ...
# 681                                     NaN  este sobre todo  ...
# 682                                     NaN              NaN  ...
#
#        Sala/Ruidos  Imagen                 Dialecto  DIST EXT OJOS  \
# 0               nd      nd                       nd            NaN
# 1               nd      nd                       nd            NaN
# 2               nd      nd                       nd            NaN
# 3               nd      nd                       nd            NaN
# 4               nd      nd                       nd            NaN
# 5               nd      nd                       nd            NaN
# 6               nd      nd                       nd            NaN
# 7               nd      nd                       nd            NaN
# 8               nd      nd                       nd            NaN
# 9               nd      nd                       nd            NaN
# 10              nd      nd                       nd            NaN
# 11              nd      nd                       nd            NaN
# 12              nd      nd                       nd            NaN
# 13              nd      nd                  andaluz            NaN
# 14            aire      nd                  andaluz            NaN
# 15            aire      nd                  andaluz            NaN
# 16            aire      nd                  andaluz            NaN
# 17            aire      nd                  frances            NaN
# 18            aire      nd                  andaluz            NaN
# 19   aire/personas      nd                  andaluz            NaN
# 20            aire      nd                  andaluz            NaN
# 21            aire      nd                  andaluz            NaN
# 22            aire      nd                  andaluz            NaN
# 23              no      nd                  andaluz            NaN
# 24            aire      nd                  andaluz            NaN
# 25            aire      nd                  andaluz            NaN
# 26            aire      nd                  andaluz            NaN
# 27            aire      nd                  andaluz            NaN
# 28          ruidos      nd  andaluz/dificultad leer            NaN
# 29          ruidos      nd                  andaluz            NaN
# ..             ...     ...                      ...            ...
# 653            432      nd           andaluz/Málaga            NaN
# 654            442      nd           andaluz/Málaga         10.440
# 655            442      nd           andaluz/Málaga         10.019
# 656            442      nd                  Francés          9.528
# 657            442      nd        andaluz/Cartagena          9.090
# 658            442      nd           andaluz/Málaga         10.245
# 659            442      nd           andaluz/Málaga          9.695
# 660            443      nd           andaluz/Málaga          9.416
# 661            443      nd           andaluz/Málaga         10.490
# 662            440      nd                 Zaragoza          9.369
# 663            442      nd           andaluz/Málaga          9.074
# 664            441      nd           andaluz/Málaga          9.200
# 665            442      nd                Cantabria          8.971
# 666            442      nd           andaluz/Málaga         10.284
# 667            442      nd           andaluz/Málaga         10.112
# 668            442      nd           andaluz/Málaga         10.512
# 669            443      nd           andaluz/Málaga          9.213
# 670            441      nd           andaluz/Málaga          9.467
# 671            445      nd           andaluz/Málaga          9.738
# 672            431      nd                     Ruso         10.026
# 673            431      nd                 Potugués          9.413
# 674            434      nd           andaluz/Málaga          9.177
# 675            435      nd           andaluz/Málaga          9.813
# 676            436      nd           andaluz/Málaga          9.753
# 677            442      nd                Argentino         10.043
# 678            443      nd           andaluz/Málaga         10.860
# 679            442      nd                   Mezcla         10.268
# 680            434      nd           andaluz/Málaga          9.181
# 681            436      nd           andaluz/Málaga          8.543
# 682            422      nd           andaluz/Málaga          8.535
#
#      DIST BARB-LOB Cansancio Concentrarse         PerdRespNoche HiperT EstHOSP
# 0              NaN       NaN          NaN                   NaN    NaN     NaN
# 1              NaN       NaN          NaN                   NaN    NaN     NaN
# 2              NaN       NaN          NaN                   NaN    NaN     NaN
# 3              NaN       NaN          NaN                   NaN    NaN     NaN
# 4              NaN       NaN          NaN                   NaN    NaN     NaN
# 5              NaN       NaN          NaN                   NaN    NaN     NaN
# 6              NaN       NaN          NaN                   NaN    NaN     NaN
# 7              NaN       NaN          NaN                   NaN    NaN     NaN
# 8              NaN       NaN          NaN                   NaN    NaN     NaN
# 9              NaN       NaN          NaN                   NaN    NaN     NaN
# 10             NaN       NaN          NaN                   NaN    NaN     NaN
# 11             NaN       NaN          NaN                   NaN    NaN     NaN
# 12             NaN       NaN          NaN                   NaN    NaN     NaN
# 13             NaN       NaN          NaN                   NaN    NaN     NaN
# 14             NaN       NaN          NaN                   NaN    NaN     NaN
# 15             NaN       NaN          NaN                   NaN    NaN     NaN
# 16             NaN       NaN          NaN                   NaN    NaN     NaN
# 17             NaN       NaN          NaN                   NaN    NaN     NaN
# 18             NaN       NaN          NaN                   NaN    NaN     NaN
# 19             NaN       NaN          NaN                   NaN    NaN     NaN
# 20             NaN       NaN          NaN                   NaN    NaN     NaN
# 21             NaN       NaN          NaN                   NaN    NaN     NaN
# 22             NaN       NaN          NaN                   NaN    NaN     NaN
# 23             NaN       NaN          NaN                   NaN    NaN     NaN
# 24             NaN       NaN          NaN                   NaN    NaN     NaN
# 25             NaN       NaN          NaN                   NaN    NaN     NaN
# 26             NaN       NaN          NaN                   NaN    NaN     NaN
# 27             NaN       NaN          NaN                   NaN    NaN     NaN
# 28             NaN       NaN          NaN                   NaN    NaN     NaN
# 29             NaN       NaN          NaN                   NaN    NaN     NaN
# ..             ...       ...          ...                   ...    ...     ...
# 653            NaN        no           no  Error? O Raro ?7,714  9.668     NaN
# 654         15.423        no           no                   NaN    NaN     NaN
# 655         13.726        si           si                   NaN    NaN     NaN
# 656         14.204        si           si                   NaN    NaN     NaN
# 657         13.724        no           no                   NaN    NaN     NaN
# 658         15.316        si           no                   NaN    NaN     NaN
# 659         13.499        si           no                     1    NaN     NaN
# 660         14.586        no           no                     1    NaN     NaN
# 661         15.773        no           no                     1  1.000     NaN
# 662         13.598        si           no                     1  1.000     0.0
# 663         13.041        si           si                     1  0.000     1.0
# 664         14.838        si           no                     0  0.000     0.0
# 665         13.002        si           si                     0  0.000     0.0
# 666         15.003        si           si                     1  1.000     1.0
# 667          14.95        si           no                     1  0.000     0.0
# 668          15.51        no           si                     0  0.000     1.0
# 669         14.658        no           no                     0  0.000     1.0
# 670         13.749        no           no                     1  1.000     1.0
# 671         14.409        si           si                     1  0.000     0.0
# 672         13.378        si           no                     0  0.000     0.0
# 673         14.447        si           si                     0  1.000     1.0
# 674         12.886        si           si                     1  1.000     1.0
# 675         13.272        si           no                     1  1.000     1.0
# 676         13.455        no           no                     1  0.000     1.0
# 677         14.919        si           no                     0  1.000     1.0
# 678         15.019        no           no                     1  1.000     1.0
# 679         14.383        si           no                     1  0.000     0.0
# 680          14.35        no           no                     1  1.000     0.0
# 681         11.956        si           si                     1  0.000     1.0
# 682         13.517        no           no                     1  1.000     NaN
#
# [683 rows x 28 columns]

# %%
columns = ['Patient', 'Gender', 'IAH', 'Peso', 'Talla', 'Edad', 'PerCervical']
df_tmp1 = pd.DataFrame(df_tmp, columns=columns)

# %%
df_tmp1.head(100)
# Out:
#    Patient  Gender    IAH   Peso  Talla  Edad  PerCervical
# 0    P0001  hombre  71.00   82.0  168.0  39.0         -1.0
# 1    P0002  hombre  29.60  119.0  174.0  56.0         48.0
# 2    P0003  hombre  56.00   -1.0   -1.0  46.0         43.0
# 3    P0004  hombre  19.70   78.0  168.0  39.0         42.0
# 4    P0005  hombre   9.00   80.0  173.0  32.0         40.0
# 5    P0006  hombre   2.00  109.0  190.0  32.0         42.0
# 6    P0007  hombre  34.00   86.0  169.0  39.0         42.0
# 7    P0008  hombre  60.00  145.0  172.0  47.0         44.0
# 8    P0009  hombre  22.00   72.0  165.0  40.0         42.0
# 9    P0010  hombre  11.00   80.0  180.0  28.0         38.0
# 10   P0011  hombre  14.20   90.0  182.0  29.0         -1.0
# 11   P0012  hombre  10.00   69.0  169.0  48.0         -1.0
# 12   P0013  hombre   3.70   90.0  180.0  36.0         40.0
# 13   P0014   mujer   7.00   50.0  158.0  50.0         35.0
# 14   P0015   mujer   5.00   55.0  156.0  62.0         38.0
# 15   P0016  hombre  26.00   95.0  166.0  77.0         46.0
# 16   P0017  hombre  22.00   88.0  173.0  56.0         46.0
# 17   P0018   mujer  10.00   90.0  158.0  60.0         39.0
# 18   P0019   mujer  15.00   65.0  152.0  59.0         36.0
# 19   P0020  hombre   4.30   89.0  171.0  44.0         45.0
# 20   P0021   mujer  20.00   63.0  169.0  32.0         32.5
# 21   P0022  hombre  56.00  113.0  177.0  33.0         46.0
# 22   P0023   mujer   4.00   60.0  162.0  53.0         33.0
# 23   P0024  hombre  53.60  107.0  170.0  48.0         46.0
# 24   P0025  hombre   2.10   70.0  174.0  53.0         38.0
# 25   P0026  hombre  27.00   77.0  178.0  33.0         42.0
# 26   P0027  hombre  47.00  100.0  180.0  62.0         48.0
# 27   P0028   mujer   5.90   74.0  155.0  53.0         38.0
# 28   P0029  hombre   9.00   93.0  185.0  44.0         41.0
# 29   P0030  hombre  32.00  105.0  185.0  70.0         47.0
# ..     ...     ...    ...    ...    ...   ...          ...
# 70   P0071  hombre   6.00   80.0  176.0  40.0         40.0
# 71   P0072   mujer   7.90   63.0  155.0  60.0         34.0
# 72   P0073   mujer   3.80   80.0  164.0  51.0         38.0
# 73   P0074  hombre  42.30  106.0  174.0  51.0         48.0
# 74   P0075  hombre  15.50   86.0  173.0  59.0         45.0
# 75   P0076  hombre  35.00   86.0  170.0  63.0         42.0
# 76   P0077  hombre   3.30  110.0  191.0  29.0         46.0
# 77   P0078  hombre  27.00   80.0  176.0  34.0         41.0
# 78   P0079  hombre   9.00   81.0  175.0  50.0         -1.0
# 79   P0080  hombre  22.00   76.0  170.0  44.0         40.0
# 80   P0081   mujer   2.50   74.0  158.0  51.0         35.0
# 81   P0082  hombre   3.00   86.0  170.0  61.0         44.0
# 82   P0083  hombre   8.40   93.0  183.0  42.0         43.0
# 83   P0084  hombre  11.80   86.0  172.0  53.0         42.0
# 84   P0085  hombre  43.36   95.0  178.0  36.0         41.0
# 85   P0086  hombre   6.40   71.0  170.0  60.0         41.0
# 86   P0087  hombre   1.20   87.0  170.0  50.0         44.0
# 87   P0088  hombre   6.30   73.0  175.0  33.0         36.0
# 88   P0089  hombre  30.00   78.0  159.0  60.0         42.0
# 89   P0090  hombre   9.50   84.0  170.0  39.0         38.0
# 90   P0091  hombre   5.40   87.0  187.0  34.0         39.0
# 91   P0092  hombre   3.00   80.0  170.0  56.0         45.0
# 92   P0093   mujer  11.00   66.0  165.0  52.0         38.0
# 93   P0094  hombre  17.30   94.0  171.0  67.0         47.0
# 94   P0095   mujer   8.80   70.0  159.0  67.0         38.0
# 95   P0096  hombre   5.00   70.0  169.0  34.0         41.0
# 96   P0097  hombre   2.20  101.0  163.0  65.0         46.0
# 97   P0098   mujer   6.30   52.0  158.0  34.0         33.0
# 98   P0099   mujer   9.50   70.0  160.0  47.0         36.0
# 99   P0100  hombre  10.90   86.0  170.0  59.0         42.0
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Look for and remove NA rows  (remember that -1 ar also NAN)

# %%
df_tmp1.isnull().sum()
# Out:
# Patient         0
# Gender          0
# IAH            34
# Peso            7
# Talla           6
# Edad            5
# PerCervical     5
# dtype: int64

# %%
df_tmp1[df_tmp1['IAH'].isnull()]
# Out:
#     Patient  Gender  IAH   Peso  Talla  Edad  PerCervical
# 260   P0261  hombre  NaN    NaN    NaN   NaN          NaN
# 299   P0300  hombre  NaN    NaN    NaN   NaN          NaN
# 314   P0315   mujer  NaN    NaN    NaN   NaN          NaN
# 331   P0332  hombre  NaN  100.0  178.0  52.0         42.0
# 429   P0430  hombre  NaN  131.0  175.0  49.0         45.0
# 441   P0442   mujer  NaN   90.0  163.0  32.0         35.0
# 444   P0445  hombre  NaN  120.0  165.0  48.0         46.0
# 461   P0462  hombre  NaN   80.0  170.0  61.0         39.0
# 469   P0470  hombre  NaN   78.0  189.0  31.0         36.0
# 490   P0491   mujer  NaN  108.0  162.0  44.0         37.0
# 492   P0493  hombre  NaN  100.0  183.0  57.0         41.0
# 493   P0494  hombre  NaN   78.0  172.0  55.0         37.0
# 504   P0505  hombre  NaN  103.0  185.0  55.0         43.0
# 511   P0512  hombre  NaN   72.0  165.0  69.0         40.0
# 525   P0526  hombre  NaN   82.0  173.0  41.0         42.0
# 538   P0539  hombre  NaN   97.0  180.0  52.0         42.0
# 539   P0540   mujer  NaN   67.0  151.0  59.0         38.0
# 548   P0549  hombre  NaN   83.0  184.0  32.0         37.0
# 558   P0559  hombre  NaN   88.0  172.0  66.0         41.0
# 561   P0562   mujer  NaN   70.0  159.0  55.0         37.0
# 563   P0564  hombre  NaN  115.0  199.0  56.0         46.0
# 600   P0601  hombre  NaN   77.0  173.0  71.0         42.0
# 602   P0603  hombre  NaN   79.0  174.0  51.0         40.0
# 623   P0624   mujer  NaN  125.0  156.0  58.0         45.0
# 630   P0631   mujer  NaN   62.0  160.0  59.0         35.0
# 634   P0635  hombre  NaN   89.0  193.0  27.0         38.0
# 635   P0636  hombre  NaN   84.0  182.0  39.0         38.0
# 637   P0638   mujer  NaN   71.0  170.0  44.0         34.0
# 640   P0641   mujer  NaN   80.0  166.0  44.0         36.0
# 649   P0650  hombre  NaN  100.0  170.0  54.0         46.0
# 659   P0660  hombre  NaN   94.0  186.0  42.0         41.0
# 670   P0671  hombre  NaN   86.0  173.0  53.0         40.0
# 677   P0678  hombre  NaN   92.0  163.0  83.0         44.0
# 680   P0681  hombre  NaN   94.0  177.0  44.0         44.0

# %%
df_tmp1[df_tmp1['Peso']==-1]
# Out:
#   Patient  Gender   IAH  Peso  Talla  Edad  PerCervical
# 2   P0003  hombre  56.0  -1.0   -1.0  46.0         43.0

# %% [markdown]
# ## Replace -1 for numpy NAN)

# %%
import numpy as np

# %%
df_tmp1 = df_tmp1.replace(-1, np.nan)

# %%
df_tmp1.head(15)
# Out:
#    Patient  Gender   IAH   Peso  Talla  Edad  PerCervical
# 0    P0001  hombre  71.0   82.0  168.0  39.0          NaN
# 1    P0002  hombre  29.6  119.0  174.0  56.0         48.0
# 2    P0003  hombre  56.0    NaN    NaN  46.0         43.0
# 3    P0004  hombre  19.7   78.0  168.0  39.0         42.0
# 4    P0005  hombre   9.0   80.0  173.0  32.0         40.0
# 5    P0006  hombre   2.0  109.0  190.0  32.0         42.0
# 6    P0007  hombre  34.0   86.0  169.0  39.0         42.0
# 7    P0008  hombre  60.0  145.0  172.0  47.0         44.0
# 8    P0009  hombre  22.0   72.0  165.0  40.0         42.0
# 9    P0010  hombre  11.0   80.0  180.0  28.0         38.0
# 10   P0011  hombre  14.2   90.0  182.0  29.0          NaN
# 11   P0012  hombre  10.0   69.0  169.0  48.0          NaN
# 12   P0013  hombre   3.7   90.0  180.0  36.0         40.0
# 13   P0014   mujer   7.0   50.0  158.0  50.0         35.0
# 14   P0015   mujer   5.0   55.0  156.0  62.0         38.0

# %% [markdown]
# ### .... now drop out all rows with NAN

# %%
df_final = df_tmp1.dropna()

# %%
df_final.head(10)
# Out:
#    Patient  Gender   IAH   Peso  Talla  Edad  PerCervical
# 1    P0002  hombre  29.6  119.0  174.0  56.0         48.0
# 3    P0004  hombre  19.7   78.0  168.0  39.0         42.0
# 4    P0005  hombre   9.0   80.0  173.0  32.0         40.0
# 5    P0006  hombre   2.0  109.0  190.0  32.0         42.0
# 6    P0007  hombre  34.0   86.0  169.0  39.0         42.0
# 7    P0008  hombre  60.0  145.0  172.0  47.0         44.0
# 8    P0009  hombre  22.0   72.0  165.0  40.0         42.0
# 9    P0010  hombre  11.0   80.0  180.0  28.0         38.0
# 12   P0013  hombre   3.7   90.0  180.0  36.0         40.0
# 13   P0014   mujer   7.0   50.0  158.0  50.0         35.0

# %%
df_final = df_final.rename(columns = {"Talla": "Height", 
                                "Peso":"Weight", 
                                "Edad": "Age",
                                "PerCervical": "Cervical"})

# %%
df_final.head(10)
# Out:
#    Patient  Gender   IAH  Weight  Height   Age  Cervical
# 1    P0002  hombre  29.6   119.0   174.0  56.0      48.0
# 3    P0004  hombre  19.7    78.0   168.0  39.0      42.0
# 4    P0005  hombre   9.0    80.0   173.0  32.0      40.0
# 5    P0006  hombre   2.0   109.0   190.0  32.0      42.0
# 6    P0007  hombre  34.0    86.0   169.0  39.0      42.0
# 7    P0008  hombre  60.0   145.0   172.0  47.0      44.0
# 8    P0009  hombre  22.0    72.0   165.0  40.0      42.0
# 9    P0010  hombre  11.0    80.0   180.0  28.0      38.0
# 12   P0013  hombre   3.7    90.0   180.0  36.0      40.0
# 13   P0014   mujer   7.0    50.0   158.0  50.0      35.0

# %%
df_final.describe()
# Out:
#               IAH      Weight      Height         Age    Cervical
# count  637.000000  637.000000  637.000000  637.000000  637.000000
# mean    20.392716   87.733124  171.284144   49.497645   40.636578
# std     18.596944   18.356730    9.558128   12.386418    3.957542
# min      0.000000   45.000000  144.000000   20.000000   30.000000
# 25%      6.400000   75.000000  165.000000   40.000000   38.000000
# 50%     14.400000   86.000000  171.000000   49.000000   41.000000
# 75%     30.000000   98.000000  178.000000   59.000000   43.000000
# max    108.600000  165.000000  197.000000   88.000000   53.000000

# %%
df_final['Gender'].describe()
# Out:
# count        637
# unique         2
# top       hombre
# freq         455
# Name: Gender, dtype: object

# %% [markdown]
# ## Write to an Excel file

# %%
df_final.to_excel (r'OSA_DB_UPM.xlsx', index = None, header=True)

# %% [markdown]
# <font size= 5 color=red>----------------------------------------------------------------</font>
# <font size= 5 color=red>----------------------------------------------------------------
#
# ## Now let's do some EDA and Train ML models using ScikitLearn
#
# </font>

# %%
# We will use OSA_df name

OSA_df = df_final

# %%
OSA_df.head(5)
# Out:
#   Patient  Gender   IAH  Weight  Height   Age  Cervical
# 1   P0002  hombre  29.6   119.0   174.0  56.0      48.0
# 3   P0004  hombre  19.7    78.0   168.0  39.0      42.0
# 4   P0005  hombre   9.0    80.0   173.0  32.0      40.0
# 5   P0006  hombre   2.0   109.0   190.0  32.0      42.0
# 6   P0007  hombre  34.0    86.0   169.0  39.0      42.0

# %%
OSA_df.dtypes
# Out:
# Patient      object
# Gender       object
# IAH         float64
# Weight      float64
# Height      float64
# Age         float64
# Cervical    float64
# dtype: object

# %%
OSA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 637 entries, P0002 to P0683
# Data columns (total 6 columns):
# Gender      637 non-null object
# IAH         637 non-null float64
# Weight      637 non-null float64
# Height      637 non-null float64
# Age         637 non-null float64
# Cervical    637 non-null float64
# dtypes: float64(5), object(1)
# memory usage: 54.8+ KB

# %% [markdown]
# ![Image Pandas Indexing](https://shanelynnwebsite-mid9n9g1q9y8tt.netdna-ssl.com/wp-content/uploads/2016/10/Pandas-selections-and-indexing-768x549.png)
# [Pandas DataFrame Indexing](https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/)

# %%
OSA_df.iloc[0:4,]
# Out:
#   Patient  Gender   IAH  Weight  Height   Age  Cervical
# 1   P0002  hombre  29.6   119.0   174.0  56.0      48.0
# 3   P0004  hombre  19.7    78.0   168.0  39.0      42.0
# 4   P0005  hombre   9.0    80.0   173.0  32.0      40.0
# 5   P0006  hombre   2.0   109.0   190.0  32.0      42.0

# %%
OSA_df.set_index("Patient", inplace=True)

# %%
OSA_df.index
# Out:
# Index(['P0002', 'P0004', 'P0005', 'P0006', 'P0007', 'P0008', 'P0009', 'P0010',
#        'P0013', 'P0014',
#        ...
#        'P0672', 'P0673', 'P0674', 'P0675', 'P0676', 'P0677', 'P0679', 'P0680',
#        'P0682', 'P0683'],
#       dtype='object', name='Patient', length=637)

# %%
OSA_df.loc[['P0002','P0006']]
# Out:
#          Gender   IAH  Weight  Height   Age  Cervical
# Patient
# P0002    hombre  29.6   119.0   174.0  56.0      48.0
# P0006    hombre   2.0   109.0   190.0  32.0      42.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(OSA_df['IAH'],OSA_df['Weight'])

# %%
OSA_df['IAH'].plot()

# %%
OSA_df['IAH'].hist()

# .describe()   .mean()

# %%
# import the scatter_matrix functionality
from pandas.plotting import scatter_matrix

# %%
axes = scatter_matrix(OSA_df, alpha=0.6, figsize=(12, 8), diagonal='hist')

# diagonal = 'kde'

# %% [markdown]
# ## [scikit-learn: Machine Learning in Python](http://scikit-learn.org/stable/)
# ![Scikit-learn Image](http://scikit-learn.org/stable/_static/scikit-learn-logo-small.png)

# %% [markdown]
# ## Python ML <font color='blue'>sklearn</font> for Multiple Linear Regression

# %%
### Picking predictor columns

# Get all the columns from the dataframe.
columns = OSA_df.columns.tolist()

# Filter the columns to remove ones we don't want.
columns = [c for c in columns if c not in ["IAH","Gender"]]

# Store the variable we'll be predicting on.
target = "IAH"

print('Predictors: ',columns)
# Out:
# Predictors:  ['Weight', 'Height', 'Age', 'Cervical']

# %%
# Splitting into train and test sets

# Generate the training set.  Set random_state to be able to replicate results.
train = OSA_df.sample(frac=0.8, random_state=1)


# Select anything not in the training set and put it in the testing set.
test = OSA_df.loc[~OSA_df.index.isin(train.index)]

# Print the shapes of both sets.
print(train.shape)
print(test.shape)
# Out:
# (510, 6)
# (127, 6)

# %% [markdown]
# ## TRAIN:

# %%
# Fitting a linear regression

# Import the linear models.
from sklearn import linear_model

# Initialize the model class.

model= linear_model.LinearRegression()

#model= linear_model.Ridge(alpha = 0.5)
# Fit the model to the training data.
Trained_model=model.fit(train[columns], train[target])

# %% [markdown]
# ## Test

# %%
### Predicting Error

# Import the scikit-learn function to compute error.
from sklearn.metrics import mean_squared_error

# Generate our predictions for the test set.
predictions = model.predict(test[columns])

# Compute error between our test predictions and the actual values.
MSE=mean_squared_error(predictions, test[target])

print('Mean squared Error: ', MSE)
# Out:
# Mean squared Error:  331.3758970696594

# %%
# Explained variance score: 
from sklearn.metrics import r2_score

print('Variance score: %.2f' % r2_score(test[target], predictions))
# Out:
# Variance score: 0.22

# %%
# Plot outputs
plt.scatter(test[target], predictions,  color='red')

plt.show()

# %% [markdown]
# ## Try improve using "feature" engineering ...  BMI, ....  (log(AHI))
